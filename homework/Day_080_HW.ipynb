# %% [markdown]
# # 請結合前面的知識與程式碼，比較不同的 optimizer 與 learning rate 組合對訓練的結果與影響
# ### 常見的 optimizer 包含
# * SGD
# * RMSprop
# * AdaGrad
# * Adam

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = [0.01, 0.001]
EPOCHS = 20
BATCH_SIZE = 256
MOMENTUM = 0.95
OPTIMIZER = ['sgd', 'rmsprop', 'adagrad', 'adam']

def getOpt(name, lr):
    if name == 'sgd':
        return keras.optimizers.SGD(lr=lr, momentum=MOMENTUM)
    elif name == 'rmsprop':
        return keras.optimizers.RMSprop(lr=lr)
    elif name == 'adagrad':
        return keras.optimizers.Adagrad(lr=lr)
    else:
        return keras.optimizers.Adam(lr=lr)

# %%
results = {}

for lr in LEARNING_RATE:
    for opt in OPTIMIZER:
        keras.backend.clear_session() # 把舊的 Graph 清掉
        print("Experiment with LEARNING_RATE = %.6f" % (lr))
        print(opt)
        model = build_mlp(input_shape=x_train.shape[1:])
        model.summary()
        optimizer = getOpt(opt, lr)
        model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

        model.fit(x_train, y_train, 
                  epochs=EPOCHS, 
                  batch_size=BATCH_SIZE, 
                  validation_data=(x_test, y_test), 
                  shuffle=True)

        # Collect results
        train_loss = model.history.history["loss"]
        valid_loss = model.history.history["val_loss"]
        train_acc = model.history.history["accuracy"]
        valid_acc = model.history.history["val_accuracy"]

        exp_name_tag = "exp-lr-%s-%s" % (str(lr) , opt)
        results[exp_name_tag] = {'train-loss': train_loss,
                                 'valid-loss': valid_loss,
                                 'train-acc': train_acc,
                                 'valid-acc': valid_acc}
# Out:
# Experiment with LEARNING_RATE = 0.010000
# sgd
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 22s 432us/step - loss: 1.8818 - accuracy: 0.3190 - val_loss: 1.7599 - val_accuracy: 0.3761
# Epoch 2/20
# 50000/50000 [==============================] - 22s 448us/step - loss: 1.6761 - accuracy: 0.3986 - val_loss: 1.6521 - val_accuracy: 0.4012
# Epoch 3/20
# 50000/50000 [==============================] - 22s 444us/step - loss: 1.6052 - accuracy: 0.4283 - val_loss: 1.5868 - val_accuracy: 0.4313
# Epoch 4/20
# 50000/50000 [==============================] - 22s 441us/step - loss: 1.5313 - accuracy: 0.4532 - val_loss: 1.5415 - val_accuracy: 0.4515
# Epoch 5/20
# 50000/50000 [==============================] - 23s 455us/step - loss: 1.4948 - accuracy: 0.4666 - val_loss: 1.5170 - val_accuracy: 0.4513
# Epoch 6/20
# 50000/50000 [==============================] - 23s 461us/step - loss: 1.4552 - accuracy: 0.4786 - val_loss: 1.4852 - val_accuracy: 0.4680
# Epoch 7/20
# 50000/50000 [==============================] - 23s 464us/step - loss: 1.4321 - accuracy: 0.4883 - val_loss: 1.4534 - val_accuracy: 0.4818
# Epoch 8/20
# 50000/50000 [==============================] - 23s 460us/step - loss: 1.3961 - accuracy: 0.5022 - val_loss: 1.4628 - val_accuracy: 0.4797
# Epoch 9/20
# 50000/50000 [==============================] - 23s 458us/step - loss: 1.3754 - accuracy: 0.5083 - val_loss: 1.4895 - val_accuracy: 0.4666
# Epoch 10/20
# 50000/50000 [==============================] - 22s 441us/step - loss: 1.3485 - accuracy: 0.5194 - val_loss: 1.4023 - val_accuracy: 0.5008
# Epoch 11/20
# 50000/50000 [==============================] - 23s 452us/step - loss: 1.3148 - accuracy: 0.5281 - val_loss: 1.3986 - val_accuracy: 0.5087
# Epoch 12/20
# 50000/50000 [==============================] - 23s 466us/step - loss: 1.2875 - accuracy: 0.5399 - val_loss: 1.4025 - val_accuracy: 0.5008
# Epoch 13/20
# 50000/50000 [==============================] - 23s 466us/step - loss: 1.2774 - accuracy: 0.5454 - val_loss: 1.3766 - val_accuracy: 0.5144
# Epoch 14/20
# 50000/50000 [==============================] - 24s 472us/step - loss: 1.2546 - accuracy: 0.5490 - val_loss: 1.3645 - val_accuracy: 0.5155
# Epoch 15/20
# 50000/50000 [==============================] - 23s 456us/step - loss: 1.2322 - accuracy: 0.5589 - val_loss: 1.3545 - val_accuracy: 0.5213
# Epoch 16/20
# 50000/50000 [==============================] - 23s 461us/step - loss: 1.2055 - accuracy: 0.5672 - val_loss: 1.4269 - val_accuracy: 0.4967
# Epoch 17/20
# 50000/50000 [==============================] - 23s 457us/step - loss: 1.1773 - accuracy: 0.5778 - val_loss: 1.3405 - val_accuracy: 0.5276
# Epoch 18/20
# 50000/50000 [==============================] - 22s 443us/step - loss: 1.1554 - accuracy: 0.5856 - val_loss: 1.3892 - val_accuracy: 0.5090
# Epoch 19/20
# 50000/50000 [==============================] - 23s 463us/step - loss: 1.1476 - accuracy: 0.5896 - val_loss: 1.3429 - val_accuracy: 0.5342
# Epoch 20/20
# 50000/50000 [==============================] - 24s 472us/step - loss: 1.1221 - accuracy: 0.5979 - val_loss: 1.3475 - val_accuracy: 0.5237
# Experiment with LEARNING_RATE = 0.010000
# rmsprop
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 24s 473us/step - loss: 9.2674 - accuracy: 0.1332 - val_loss: 2.1841 - val_accuracy: 0.1405
# Epoch 2/20
# 50000/50000 [==============================] - 24s 488us/step - loss: 2.1707 - accuracy: 0.1739 - val_loss: 2.1002 - val_accuracy: 0.1652
# Epoch 3/20
# 50000/50000 [==============================] - 24s 489us/step - loss: 2.0939 - accuracy: 0.2118 - val_loss: 2.0209 - val_accuracy: 0.2264
# Epoch 4/20
# 50000/50000 [==============================] - 23s 469us/step - loss: 2.0131 - accuracy: 0.2487 - val_loss: 2.0841 - val_accuracy: 0.2345
# Epoch 5/20
# 50000/50000 [==============================] - 25s 510us/step - loss: 1.9949 - accuracy: 0.2653 - val_loss: 2.0430 - val_accuracy: 0.2198
# Epoch 6/20
# 50000/50000 [==============================] - 25s 496us/step - loss: 1.9408 - accuracy: 0.2759 - val_loss: 1.9924 - val_accuracy: 0.2514
# Epoch 7/20
# 50000/50000 [==============================] - 25s 507us/step - loss: 1.9243 - accuracy: 0.2849 - val_loss: 2.1010 - val_accuracy: 0.2478
# Epoch 8/20
# 50000/50000 [==============================] - 27s 542us/step - loss: 1.9104 - accuracy: 0.2888 - val_loss: 1.9877 - val_accuracy: 0.2505
# Epoch 9/20
# 50000/50000 [==============================] - 23s 470us/step - loss: 1.8996 - accuracy: 0.2901 - val_loss: 1.9299 - val_accuracy: 0.2778
# Epoch 10/20
# 50000/50000 [==============================] - 26s 528us/step - loss: 1.8897 - accuracy: 0.2959 - val_loss: 1.8654 - val_accuracy: 0.3087
# Epoch 11/20
# 50000/50000 [==============================] - 25s 506us/step - loss: 1.8847 - accuracy: 0.2971 - val_loss: 1.9831 - val_accuracy: 0.2642
# Epoch 12/20
# 50000/50000 [==============================] - 25s 502us/step - loss: 1.8801 - accuracy: 0.2962 - val_loss: 1.8772 - val_accuracy: 0.2930
# Epoch 13/20
# 50000/50000 [==============================] - 23s 456us/step - loss: 1.8789 - accuracy: 0.2990 - val_loss: 1.8822 - val_accuracy: 0.2980
# Epoch 14/20
# 50000/50000 [==============================] - 26s 517us/step - loss: 1.8719 - accuracy: 0.3031 - val_loss: 1.8439 - val_accuracy: 0.3070
# Epoch 15/20
# 50000/50000 [==============================] - 26s 516us/step - loss: 1.8669 - accuracy: 0.3039 - val_loss: 1.9903 - val_accuracy: 0.2717
# Epoch 16/20
# 50000/50000 [==============================] - 24s 487us/step - loss: 1.8647 - accuracy: 0.3033 - val_loss: 1.8615 - val_accuracy: 0.3057
# Epoch 17/20
# 50000/50000 [==============================] - 24s 481us/step - loss: 1.8605 - accuracy: 0.3037 - val_loss: 1.8923 - val_accuracy: 0.2861
# Epoch 18/20
# 50000/50000 [==============================] - 25s 505us/step - loss: 1.8593 - accuracy: 0.3055 - val_loss: 1.8733 - val_accuracy: 0.2975
# Epoch 19/20
# 50000/50000 [==============================] - 27s 536us/step - loss: 1.8544 - accuracy: 0.3100 - val_loss: 1.8363 - val_accuracy: 0.3021
# Epoch 20/20
# 50000/50000 [==============================] - 25s 507us/step - loss: 1.8503 - accuracy: 0.3080 - val_loss: 1.8104 - val_accuracy: 0.3169
# Experiment with LEARNING_RATE = 0.010000
# adagrad
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 22s 433us/step - loss: 3.1258 - accuracy: 0.2343 - val_loss: 1.8949 - val_accuracy: 0.3256
# Epoch 2/20
# 50000/50000 [==============================] - 21s 425us/step - loss: 1.8559 - accuracy: 0.3325 - val_loss: 1.8511 - val_accuracy: 0.3197
# Epoch 3/20
# 50000/50000 [==============================] - 22s 449us/step - loss: 1.7641 - accuracy: 0.3689 - val_loss: 1.8128 - val_accuracy: 0.3375
# Epoch 4/20
# 50000/50000 [==============================] - 25s 502us/step - loss: 1.7001 - accuracy: 0.3939 - val_loss: 1.7215 - val_accuracy: 0.3766
# Epoch 5/20
# 50000/50000 [==============================] - 22s 441us/step - loss: 1.6580 - accuracy: 0.4097 - val_loss: 1.6914 - val_accuracy: 0.3942
# Epoch 6/20
# 50000/50000 [==============================] - 22s 441us/step - loss: 1.6139 - accuracy: 0.4268 - val_loss: 1.6588 - val_accuracy: 0.4071
# Epoch 7/20
# 50000/50000 [==============================] - 22s 445us/step - loss: 1.5860 - accuracy: 0.4372 - val_loss: 1.5842 - val_accuracy: 0.4345
# Epoch 8/20
# 50000/50000 [==============================] - 22s 446us/step - loss: 1.5493 - accuracy: 0.4541 - val_loss: 1.7518 - val_accuracy: 0.3665
# Epoch 9/20
# 50000/50000 [==============================] - 22s 449us/step - loss: 1.5263 - accuracy: 0.4601 - val_loss: 1.5560 - val_accuracy: 0.4494
# Epoch 10/20
# 50000/50000 [==============================] - 22s 448us/step - loss: 1.5042 - accuracy: 0.4681 - val_loss: 1.5806 - val_accuracy: 0.4328
# Epoch 11/20
# 50000/50000 [==============================] - 22s 449us/step - loss: 1.4778 - accuracy: 0.4784 - val_loss: 1.5973 - val_accuracy: 0.4319
# Epoch 12/20
# 50000/50000 [==============================] - 22s 444us/step - loss: 1.4567 - accuracy: 0.4866 - val_loss: 1.5211 - val_accuracy: 0.4647
# Epoch 13/20
# 50000/50000 [==============================] - 22s 449us/step - loss: 1.4433 - accuracy: 0.4884 - val_loss: 1.6306 - val_accuracy: 0.4158
# Epoch 14/20
# 50000/50000 [==============================] - 22s 449us/step - loss: 1.4223 - accuracy: 0.4976 - val_loss: 1.5188 - val_accuracy: 0.4581
# Epoch 15/20
# 50000/50000 [==============================] - 23s 466us/step - loss: 1.4063 - accuracy: 0.5024 - val_loss: 1.5391 - val_accuracy: 0.4466
# Epoch 16/20
# 50000/50000 [==============================] - 22s 448us/step - loss: 1.3892 - accuracy: 0.5088 - val_loss: 1.5355 - val_accuracy: 0.4604
# Epoch 17/20
# 50000/50000 [==============================] - 23s 451us/step - loss: 1.3738 - accuracy: 0.5144 - val_loss: 1.4448 - val_accuracy: 0.4881
# Epoch 18/20
# 50000/50000 [==============================] - 22s 450us/step - loss: 1.3587 - accuracy: 0.5215 - val_loss: 1.4244 - val_accuracy: 0.4920
# Epoch 19/20
# 50000/50000 [==============================] - 24s 480us/step - loss: 1.3470 - accuracy: 0.5256 - val_loss: 1.5015 - val_accuracy: 0.4768
# Epoch 20/20
# 50000/50000 [==============================] - 23s 451us/step - loss: 1.3337 - accuracy: 0.5282 - val_loss: 1.4763 - val_accuracy: 0.4773
# Experiment with LEARNING_RATE = 0.010000
# adam
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 28s 569us/step - loss: 3.0952 - accuracy: 0.2294 - val_loss: 1.9137 - val_accuracy: 0.2830
# Epoch 2/20
# 50000/50000 [==============================] - 22s 446us/step - loss: 1.8598 - accuracy: 0.3166 - val_loss: 1.8457 - val_accuracy: 0.3215
# Epoch 3/20
# 50000/50000 [==============================] - 22s 441us/step - loss: 1.8182 - accuracy: 0.3357 - val_loss: 1.8380 - val_accuracy: 0.3302
# Epoch 4/20
# 50000/50000 [==============================] - 22s 439us/step - loss: 1.7942 - accuracy: 0.3475 - val_loss: 1.7816 - val_accuracy: 0.3474
# Epoch 5/20
# 50000/50000 [==============================] - 22s 445us/step - loss: 1.7805 - accuracy: 0.3519 - val_loss: 1.7467 - val_accuracy: 0.3669
# Epoch 6/20
# 50000/50000 [==============================] - 22s 444us/step - loss: 1.7708 - accuracy: 0.3530 - val_loss: 1.7535 - val_accuracy: 0.3581
# Epoch 7/20
# 50000/50000 [==============================] - 23s 450us/step - loss: 1.7525 - accuracy: 0.3610 - val_loss: 1.7421 - val_accuracy: 0.3658
# Epoch 8/20
# 50000/50000 [==============================] - 22s 443us/step - loss: 1.7593 - accuracy: 0.3579 - val_loss: 1.8581 - val_accuracy: 0.3227
# Epoch 9/20
# 50000/50000 [==============================] - 22s 445us/step - loss: 1.7509 - accuracy: 0.3605 - val_loss: 1.7486 - val_accuracy: 0.3624
# Epoch 10/20
# 50000/50000 [==============================] - 22s 445us/step - loss: 1.7491 - accuracy: 0.3629 - val_loss: 1.7438 - val_accuracy: 0.3634
# Epoch 11/20
# 50000/50000 [==============================] - 22s 442us/step - loss: 1.7370 - accuracy: 0.3652 - val_loss: 1.7252 - val_accuracy: 0.3788
# Epoch 12/20
# 50000/50000 [==============================] - 22s 439us/step - loss: 1.7292 - accuracy: 0.3675 - val_loss: 1.7280 - val_accuracy: 0.3769
# Epoch 13/20
# 50000/50000 [==============================] - 22s 442us/step - loss: 1.7309 - accuracy: 0.3658 - val_loss: 1.7798 - val_accuracy: 0.3493
# Epoch 14/20
# 50000/50000 [==============================] - 22s 440us/step - loss: 1.7196 - accuracy: 0.3698 - val_loss: 1.7499 - val_accuracy: 0.3566
# Epoch 15/20
# 50000/50000 [==============================] - 22s 441us/step - loss: 1.7240 - accuracy: 0.3693 - val_loss: 1.7627 - val_accuracy: 0.3547
# Epoch 16/20
# 50000/50000 [==============================] - 25s 494us/step - loss: 1.7198 - accuracy: 0.3723 - val_loss: 1.7831 - val_accuracy: 0.3502
# Epoch 17/20
# 50000/50000 [==============================] - 31s 618us/step - loss: 1.7096 - accuracy: 0.3743 - val_loss: 1.7229 - val_accuracy: 0.3739
# Epoch 18/20
# 50000/50000 [==============================] - 28s 568us/step - loss: 1.7094 - accuracy: 0.3750 - val_loss: 1.7575 - val_accuracy: 0.3659
# Epoch 19/20
# 50000/50000 [==============================] - 25s 503us/step - loss: 1.7125 - accuracy: 0.3715 - val_loss: 1.7187 - val_accuracy: 0.3769
# Epoch 20/20
# 50000/50000 [==============================] - 33s 652us/step - loss: 1.7024 - accuracy: 0.3801 - val_loss: 1.7731 - val_accuracy: 0.3551
# Experiment with LEARNING_RATE = 0.001000
# sgd
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 24s 487us/step - loss: 2.0213 - accuracy: 0.2637 - val_loss: 1.8768 - val_accuracy: 0.3409
# Epoch 2/20
# 50000/50000 [==============================] - 21s 423us/step - loss: 1.8185 - accuracy: 0.3539 - val_loss: 1.7725 - val_accuracy: 0.3709
# Epoch 3/20
# 50000/50000 [==============================] - 22s 440us/step - loss: 1.7321 - accuracy: 0.3881 - val_loss: 1.7104 - val_accuracy: 0.3950
# Epoch 4/20
# 50000/50000 [==============================] - 21s 427us/step - loss: 1.6829 - accuracy: 0.4049 - val_loss: 1.6653 - val_accuracy: 0.4099
# Epoch 5/20
# 50000/50000 [==============================] - 21s 422us/step - loss: 1.6355 - accuracy: 0.4230 - val_loss: 1.6201 - val_accuracy: 0.4271
# Epoch 6/20
# 50000/50000 [==============================] - 22s 432us/step - loss: 1.5930 - accuracy: 0.4369 - val_loss: 1.5848 - val_accuracy: 0.4385
# Epoch 7/20
# 50000/50000 [==============================] - 21s 419us/step - loss: 1.5591 - accuracy: 0.4483 - val_loss: 1.5565 - val_accuracy: 0.4483
# Epoch 8/20
# 50000/50000 [==============================] - 21s 423us/step - loss: 1.5321 - accuracy: 0.4587 - val_loss: 1.5295 - val_accuracy: 0.4610
# Epoch 9/20
# 50000/50000 [==============================] - 21s 415us/step - loss: 1.5161 - accuracy: 0.4647 - val_loss: 1.5385 - val_accuracy: 0.4587
# Epoch 10/20
# 50000/50000 [==============================] - 21s 415us/step - loss: 1.4851 - accuracy: 0.4768 - val_loss: 1.5021 - val_accuracy: 0.4675
# Epoch 11/20
# 50000/50000 [==============================] - 22s 440us/step - loss: 1.4609 - accuracy: 0.4826 - val_loss: 1.4924 - val_accuracy: 0.4688
# Epoch 12/20
# 50000/50000 [==============================] - 22s 446us/step - loss: 1.4396 - accuracy: 0.4901 - val_loss: 1.4645 - val_accuracy: 0.4811
# Epoch 13/20
# 50000/50000 [==============================] - 22s 448us/step - loss: 1.4185 - accuracy: 0.4982 - val_loss: 1.4512 - val_accuracy: 0.4784
# Epoch 14/20
# 50000/50000 [==============================] - 21s 425us/step - loss: 1.4003 - accuracy: 0.5053 - val_loss: 1.5006 - val_accuracy: 0.4668
# Epoch 15/20
# 50000/50000 [==============================] - 21s 425us/step - loss: 1.3924 - accuracy: 0.5070 - val_loss: 1.4391 - val_accuracy: 0.4809
# Epoch 16/20
# 50000/50000 [==============================] - 21s 423us/step - loss: 1.3704 - accuracy: 0.5142 - val_loss: 1.4290 - val_accuracy: 0.4899
# Epoch 17/20
# 50000/50000 [==============================] - 22s 430us/step - loss: 1.3590 - accuracy: 0.5206 - val_loss: 1.4052 - val_accuracy: 0.4949
# Epoch 18/20
# 50000/50000 [==============================] - 21s 426us/step - loss: 1.3356 - accuracy: 0.5278 - val_loss: 1.4024 - val_accuracy: 0.5011
# Epoch 19/20
# 50000/50000 [==============================] - 21s 426us/step - loss: 1.3212 - accuracy: 0.5317 - val_loss: 1.3939 - val_accuracy: 0.4969
# Epoch 20/20
# 50000/50000 [==============================] - 21s 424us/step - loss: 1.3008 - accuracy: 0.5406 - val_loss: 1.3981 - val_accuracy: 0.4995
# Experiment with LEARNING_RATE = 0.001000
# rmsprop
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 23s 464us/step - loss: 2.2968 - accuracy: 0.2125 - val_loss: 1.9141 - val_accuracy: 0.2976
# Epoch 2/20
# 50000/50000 [==============================] - 23s 459us/step - loss: 1.8834 - accuracy: 0.3205 - val_loss: 1.8049 - val_accuracy: 0.3441
# Epoch 3/20
# 50000/50000 [==============================] - 22s 449us/step - loss: 1.7773 - accuracy: 0.3600 - val_loss: 1.7425 - val_accuracy: 0.3714
# Epoch 4/20
# 50000/50000 [==============================] - 23s 457us/step - loss: 1.7085 - accuracy: 0.3875 - val_loss: 1.6549 - val_accuracy: 0.4030
# Epoch 5/20
# 50000/50000 [==============================] - 23s 455us/step - loss: 1.6490 - accuracy: 0.4114 - val_loss: 1.6831 - val_accuracy: 0.4031
# Epoch 6/20
# 50000/50000 [==============================] - 23s 457us/step - loss: 1.6041 - accuracy: 0.4274 - val_loss: 1.7414 - val_accuracy: 0.3849
# Epoch 7/20
# 50000/50000 [==============================] - 24s 471us/step - loss: 1.5657 - accuracy: 0.4404 - val_loss: 1.6124 - val_accuracy: 0.4258
# Epoch 8/20
# 50000/50000 [==============================] - 23s 453us/step - loss: 1.5271 - accuracy: 0.4552 - val_loss: 1.8767 - val_accuracy: 0.3476
# Epoch 9/20
# 50000/50000 [==============================] - 23s 452us/step - loss: 1.5009 - accuracy: 0.4652 - val_loss: 1.5592 - val_accuracy: 0.4426
# Epoch 10/20
# 50000/50000 [==============================] - 22s 448us/step - loss: 1.4681 - accuracy: 0.4756 - val_loss: 1.5142 - val_accuracy: 0.4633
# Epoch 11/20
# 50000/50000 [==============================] - 23s 454us/step - loss: 1.4416 - accuracy: 0.4872 - val_loss: 1.5861 - val_accuracy: 0.4422
# Epoch 12/20
# 50000/50000 [==============================] - 23s 457us/step - loss: 1.4142 - accuracy: 0.4943 - val_loss: 1.6592 - val_accuracy: 0.4250
# Epoch 13/20
# 50000/50000 [==============================] - 23s 461us/step - loss: 1.3899 - accuracy: 0.5048 - val_loss: 1.6578 - val_accuracy: 0.4170
# Epoch 14/20
# 50000/50000 [==============================] - 23s 455us/step - loss: 1.3643 - accuracy: 0.5137 - val_loss: 1.6676 - val_accuracy: 0.4126
# Epoch 15/20
# 50000/50000 [==============================] - 23s 450us/step - loss: 1.3391 - accuracy: 0.5217 - val_loss: 1.5094 - val_accuracy: 0.4693
# Epoch 16/20
# 50000/50000 [==============================] - 22s 432us/step - loss: 1.3205 - accuracy: 0.5291 - val_loss: 1.5336 - val_accuracy: 0.4631
# Epoch 17/20
# 50000/50000 [==============================] - 22s 431us/step - loss: 1.2952 - accuracy: 0.5382 - val_loss: 1.5028 - val_accuracy: 0.4721
# Epoch 18/20
# 50000/50000 [==============================] - 22s 437us/step - loss: 1.2770 - accuracy: 0.5461 - val_loss: 1.5791 - val_accuracy: 0.4543
# Epoch 19/20
# 50000/50000 [==============================] - 23s 467us/step - loss: 1.2541 - accuracy: 0.5534 - val_loss: 1.5551 - val_accuracy: 0.4554
# Epoch 20/20
# 50000/50000 [==============================] - 24s 475us/step - loss: 1.2371 - accuracy: 0.5596 - val_loss: 1.5836 - val_accuracy: 0.4625
# Experiment with LEARNING_RATE = 0.001000
# adagrad
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 20s 396us/step - loss: 2.0156 - accuracy: 0.2722 - val_loss: 1.9504 - val_accuracy: 0.2935
# Epoch 2/20
# 50000/50000 [==============================] - 20s 392us/step - loss: 1.8153 - accuracy: 0.3598 - val_loss: 1.7802 - val_accuracy: 0.3693
# Epoch 3/20
# 50000/50000 [==============================] - 20s 397us/step - loss: 1.7358 - accuracy: 0.3907 - val_loss: 1.7728 - val_accuracy: 0.3587
# Epoch 4/20
# 50000/50000 [==============================] - 25s 503us/step - loss: 1.6830 - accuracy: 0.4121 - val_loss: 1.7151 - val_accuracy: 0.3923
# Epoch 5/20
# 50000/50000 [==============================] - 22s 436us/step - loss: 1.6476 - accuracy: 0.4242 - val_loss: 1.6327 - val_accuracy: 0.4369
# Epoch 6/20
# 50000/50000 [==============================] - 22s 441us/step - loss: 1.6159 - accuracy: 0.4344 - val_loss: 1.6617 - val_accuracy: 0.4181
# Epoch 7/20
# 50000/50000 [==============================] - 22s 446us/step - loss: 1.5935 - accuracy: 0.4432 - val_loss: 1.5954 - val_accuracy: 0.4481
# Epoch 8/20
# 50000/50000 [==============================] - 22s 444us/step - loss: 1.5744 - accuracy: 0.4518 - val_loss: 1.5899 - val_accuracy: 0.4414
# Epoch 9/20
# 50000/50000 [==============================] - 23s 453us/step - loss: 1.5560 - accuracy: 0.4574 - val_loss: 1.5687 - val_accuracy: 0.4441
# Epoch 10/20
# 50000/50000 [==============================] - 22s 447us/step - loss: 1.5418 - accuracy: 0.4615 - val_loss: 1.5659 - val_accuracy: 0.4448
# Epoch 11/20
# 50000/50000 [==============================] - 22s 444us/step - loss: 1.5267 - accuracy: 0.4659 - val_loss: 1.5614 - val_accuracy: 0.4489
# Epoch 12/20
# 50000/50000 [==============================] - 22s 445us/step - loss: 1.5132 - accuracy: 0.4708 - val_loss: 1.5543 - val_accuracy: 0.4447
# Epoch 13/20
# 50000/50000 [==============================] - 22s 449us/step - loss: 1.5012 - accuracy: 0.4757 - val_loss: 1.5269 - val_accuracy: 0.4551
# Epoch 14/20
# 50000/50000 [==============================] - 23s 454us/step - loss: 1.4884 - accuracy: 0.4809 - val_loss: 1.5161 - val_accuracy: 0.4647
# Epoch 15/20
# 50000/50000 [==============================] - 22s 448us/step - loss: 1.4775 - accuracy: 0.4835 - val_loss: 1.5054 - val_accuracy: 0.4688
# Epoch 16/20
# 50000/50000 [==============================] - 22s 445us/step - loss: 1.4671 - accuracy: 0.4889 - val_loss: 1.5183 - val_accuracy: 0.4710
# Epoch 17/20
# 50000/50000 [==============================] - 22s 447us/step - loss: 1.4583 - accuracy: 0.4901 - val_loss: 1.5081 - val_accuracy: 0.4698
# Epoch 18/20
# 50000/50000 [==============================] - 22s 448us/step - loss: 1.4474 - accuracy: 0.4953 - val_loss: 1.5332 - val_accuracy: 0.4610
# Epoch 19/20
# 50000/50000 [==============================] - 23s 462us/step - loss: 1.4396 - accuracy: 0.4967 - val_loss: 1.4769 - val_accuracy: 0.4801
# Epoch 20/20
# 50000/50000 [==============================] - 23s 458us/step - loss: 1.4305 - accuracy: 0.5016 - val_loss: 1.4786 - val_accuracy: 0.4779
# Experiment with LEARNING_RATE = 0.001000
# adam
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 25s 506us/step - loss: 1.9212 - accuracy: 0.3051 - val_loss: 1.8263 - val_accuracy: 0.3392
# Epoch 2/20
# 50000/50000 [==============================] - 25s 496us/step - loss: 1.7080 - accuracy: 0.3875 - val_loss: 1.6440 - val_accuracy: 0.4096
# Epoch 3/20
# 50000/50000 [==============================] - 25s 500us/step - loss: 1.6113 - accuracy: 0.4245 - val_loss: 1.6547 - val_accuracy: 0.4058
# Epoch 4/20
# 50000/50000 [==============================] - 26s 519us/step - loss: 1.5620 - accuracy: 0.4434 - val_loss: 1.5626 - val_accuracy: 0.4489
# Epoch 5/20
# 50000/50000 [==============================] - 27s 535us/step - loss: 1.5031 - accuracy: 0.4644 - val_loss: 1.5161 - val_accuracy: 0.4571
# Epoch 6/20
# 50000/50000 [==============================] - 27s 549us/step - loss: 1.4597 - accuracy: 0.4787 - val_loss: 1.5015 - val_accuracy: 0.4661
# Epoch 7/20
# 50000/50000 [==============================] - 25s 508us/step - loss: 1.4238 - accuracy: 0.4933 - val_loss: 1.4587 - val_accuracy: 0.4876
# Epoch 8/20
# 50000/50000 [==============================] - 25s 503us/step - loss: 1.4071 - accuracy: 0.4966 - val_loss: 1.4657 - val_accuracy: 0.4791
# Epoch 9/20
# 50000/50000 [==============================] - 26s 526us/step - loss: 1.3728 - accuracy: 0.5130 - val_loss: 1.4745 - val_accuracy: 0.4639
# Epoch 10/20
# 50000/50000 [==============================] - 25s 506us/step - loss: 1.3472 - accuracy: 0.5204 - val_loss: 1.4609 - val_accuracy: 0.4814
# Epoch 11/20
# 50000/50000 [==============================] - 26s 512us/step - loss: 1.3165 - accuracy: 0.5312 - val_loss: 1.4255 - val_accuracy: 0.4912
# Epoch 12/20
# 50000/50000 [==============================] - 25s 503us/step - loss: 1.2951 - accuracy: 0.5398 - val_loss: 1.4039 - val_accuracy: 0.5081
# Epoch 13/20
# 50000/50000 [==============================] - 25s 502us/step - loss: 1.2647 - accuracy: 0.5496 - val_loss: 1.4058 - val_accuracy: 0.5028
# Epoch 14/20
# 50000/50000 [==============================] - 25s 508us/step - loss: 1.2452 - accuracy: 0.5557 - val_loss: 1.3822 - val_accuracy: 0.5101
# Epoch 15/20
# 50000/50000 [==============================] - 25s 504us/step - loss: 1.2275 - accuracy: 0.5631 - val_loss: 1.4043 - val_accuracy: 0.5012
# Epoch 16/20
# 50000/50000 [==============================] - 25s 502us/step - loss: 1.2036 - accuracy: 0.5738 - val_loss: 1.3735 - val_accuracy: 0.5134
# Epoch 17/20
# 50000/50000 [==============================] - 25s 502us/step - loss: 1.1864 - accuracy: 0.5772 - val_loss: 1.4234 - val_accuracy: 0.5057
# Epoch 18/20
# 50000/50000 [==============================] - 26s 518us/step - loss: 1.1566 - accuracy: 0.5876 - val_loss: 1.3731 - val_accuracy: 0.5229
# Epoch 19/20
# 50000/50000 [==============================] - 26s 526us/step - loss: 1.1399 - accuracy: 0.5964 - val_loss: 1.3699 - val_accuracy: 0.5116
# Epoch 20/20
# 50000/50000 [==============================] - 24s 485us/step - loss: 1.1217 - accuracy: 0.6009 - val_loss: 1.4005 - val_accuracy: 0.5156

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
color_bar = ["r", "g", "b", "y", "m", "k", "c", "0.8"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

# %%
# sgd 0.01 和 adam 0.001 表現較好
