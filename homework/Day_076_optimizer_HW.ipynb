# %% [markdown]
# # 作業重點:
#
# (1)以, Adam, 為例, 調整 batch_size, epoch , 觀察accurancy, loss 的變化
#
# (2)以同一模型, 分別驗證 SGD, Adam, Rmsprop 的 accurancy

# %% [markdown]
# # 作業目標:
#
#     取得各種優化器的運算結果

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
from keras import optimizers
import matplotlib.pyplot as plt
import numpy 
import pickle
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
#Blas GEMM launch failed , 避免動態分配GPU / CPU, 出現問題
import tensorflow as tf
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))

# %%
batch_size = 512
num_classes = 10
epochs = 6
data_augmentation = True
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'Day076_saved_models')
model_name = 'keras_cifar10_trained_model.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

# %%
# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
#    第一步：選擇模型, 順序模型是多個網絡層的線性堆疊
 
model = Sequential()

#   第二步：構建網絡層
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense( 10)) # 輸出結果是10個類別，所以維度是10   
model.add(Activation('softmax')) # 最後一層用softmax作為激活函數

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
init_model_file_name = 'Day076init_model'
model_path = os.path.join(save_dir, init_model_file_name)
model.save(model_path)

# %%
# 模型建立完成後，統計參數總量
print("Total Parameters：%d" % model.count_params())
# Out:
# Total Parameters：1250858

# %%
# 輸出模型摘要資訊
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        18496
# ...

# %%
#第三步編譯
'''
SGD(隨機梯度下降) - Arguments
lr: float >= 0. Learning rate.
momentum: float >= 0. Parameter that accelerates SGD in the relevant direction and dampens oscillations.
decay: float >= 0. Learning rate decay over each update.
nesterov: boolean. Whether to apply Nesterov momentum.
'''

'''
RMSprop- Arguments
lr: float >= 0. Learning rate.
rho: float >= 0.
epsilon: float >= 0. Fuzz factor. If None, defaults to K.epsilon().
decay: float >= 0. Learning rate decay over each update.
'''

'''
Example:
opt = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

'''
opt = optimizers.Adam()
model.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
# 資料正規化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
history=None
datagen=None
def myFit():
    global history
    global datagen
    # 是否要做資料處理
    if not data_augmentation:
        print('Not using data augmentation.')
        history=model.fit(x_train, y_train,
                  batch_size=batch_size,
                  epochs=epochs,
                  validation_data=(x_test, y_test),
                  shuffle=True)
    else:
        print('Using real-time data augmentation.')
        print('')

        # This will do preprocessing and realtime data augmentation:
        datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            zca_epsilon=1e-06,  # epsilon for ZCA whitening
            rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
            # randomly shift images horizontally (fraction of total width)
            width_shift_range=0.1,
            # randomly shift images vertically (fraction of total height)
            height_shift_range=0.1,
            shear_range=0.,  # set range for random shear
            zoom_range=0.,  # set range for random zoom
            channel_shift_range=0.,  # set range for random channel shifts
            # set mode for filling points outside the input boundaries
            fill_mode='nearest',
            cval=0.,  # value used for fill_mode = "constant"
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False,  # randomly flip images
            # set rescaling factor (applied before any other transformation)
            rescale=None,
            # set function that will be applied on each input
            preprocessing_function=None,
            # image data format, either "channels_first" or "channels_last"
            data_format=None,
            # fraction of images reserved for validation (strictly between 0 and 1)
            validation_split=0.0)

        # Compute quantities required for feature-wise normalization
        # (std, mean, and principal components if ZCA whitening is applied).
        datagen.fit(x_train)
        history=model.fit(x_train, y_train,
                  batch_size=batch_size,
                  epochs=epochs,
                  validation_data=(x_test, y_test),
                  shuffle=True)   

    '''
       第四步：訓練
       .fit的一些參數
       batch_size：對總的樣本數進行分組，每組包含的樣本數量
       epochs ：訓練次數
       shuffle：是否把數據隨機打亂之後再進行訓練
       validation_split：拿出百分之多少用來做交叉驗證
       verbose：屏顯模式 - 0：不輸出, 1：輸出進度, 2：輸出每次的訓練結果
    '''

# %% [markdown]
# # adam, batch_size 512 , epochs 6

# %%
try:
    model=keras.models.load_model(os.path.join(save_dir, 'Day076_adam_batch512_epo6_model'))
    with open(os.path.join(save_dir, 'Day076_adam_batch512_epo6_history'), 'rb') as file:
        history=pickle.load(file)
except:
    myFit()
    model.save(os.path.join(save_dir, 'Day076_adam_batch512_epo6_model'))
    with open(os.path.join(save_dir, 'Day076_adam_batch512_epo6_history'), 'wb') as file:
        pickle.dump(history, file)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Using real-time data augmentation.
#
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/6
# 50000/50000 [==============================] - 305s 6ms/step - loss: 1.8054 - accuracy: 0.3343 - val_loss: 1.4744 - val_accuracy: 0.4675
# Epoch 2/6
# 50000/50000 [==============================] - 306s 6ms/step - loss: 1.4197 - accuracy: 0.4856 - val_loss: 1.2722 - val_accuracy: 0.5471
# Epoch 3/6
# 50000/50000 [==============================] - 303s 6ms/step - loss: 1.2530 - accuracy: 0.5506 - val_loss: 1.1080 - val_accuracy: 0.6062
# Epoch 4/6
# 50000/50000 [==============================] - 302s 6ms/step - loss: 1.1317 - accuracy: 0.5976 - val_loss: 1.0226 - val_accuracy: 0.6315
# Epoch 5/6
# 50000/50000 [==============================] - 301s 6ms/step - loss: 1.0464 - accuracy: 0.6291 - val_loss: 0.9359 - val_accuracy: 0.6699
# Epoch 6/6
# ...
# 10000/10000 [==============================] - 21s 2ms/step
# Test loss: 0.9374399150848388
# Test accuracy: 0.6783999800682068

# %%
#    第六步：輸出

print ( " test set " )
scores = model.evaluate(x_test,y_test,batch_size=200,verbose= 0)
print ( "" )
print ( " The test loss is %f ", scores)


result = model.predict(x_test,batch_size=200,verbose= 0)

result_max = numpy.argmax(result, axis = 1 )
test_max = numpy.argmax(y_test, axis = 1 )

result_bool = numpy.equal(result_max, test_max)
true_num = numpy.sum(result_bool)
# Out:
#  test set
#
#  The test loss is %f  [0.9374399030208588, 0.6783999800682068]

# %%
def myPlot():
    global history
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Valiidation'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Valiidation'], loc='upper left')
    plt.show()
myPlot()

# %% [markdown]
# # adam, batch_size 512 , epochs 4

# %%
batch_size = 512
epochs = 4

model_path = os.path.join(save_dir, init_model_file_name)
model=keras.models.load_model(model_path)

opt = optimizers.Adam()
model.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

try:
    model=keras.models.load_model(os.path.join(save_dir, 'Day076_adam_batch512_epo4_model'))
    with open(os.path.join(save_dir, 'Day076_adam_batch512_epo4_history'), 'rb') as file:
        history=pickle.load(file)
except:
    myFit()
    model.save(os.path.join(save_dir, 'Day076_adam_batch512_epo4_model'))
    with open(os.path.join(save_dir, 'Day076_adam_batch512_epo4_history'), 'wb') as file:
        pickle.dump(history, file)

scores = model.evaluate(x_test,y_test,batch_size=200,verbose=0)
print ( " The test loss is %f ", scores)

myPlot()
# Out:
# Using real-time data augmentation.
#
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 299s 6ms/step - loss: 1.8315 - accuracy: 0.3242 - val_loss: 1.5286 - val_accuracy: 0.4432
# Epoch 2/4
# 50000/50000 [==============================] - 299s 6ms/step - loss: 1.4489 - accuracy: 0.4704 - val_loss: 1.2650 - val_accuracy: 0.5453
# Epoch 3/4
# 50000/50000 [==============================] - 299s 6ms/step - loss: 1.2652 - accuracy: 0.5465 - val_loss: 1.1140 - val_accuracy: 0.6122
# Epoch 4/4
# 50000/50000 [==============================] - 298s 6ms/step - loss: 1.1486 - accuracy: 0.5925 - val_loss: 1.0574 - val_accuracy: 0.6329
#  The test loss is %f  [1.0573681998252868, 0.6328999996185303]

# %% [markdown]
# # adam, batch_size 32 , epochs 4

# %%
batch_size = 32
epochs = 4

model_path = os.path.join(save_dir, init_model_file_name)
model=keras.models.load_model(model_path)

opt = optimizers.Adam()
model.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

try:
    model=keras.models.load_model(os.path.join(save_dir, 'Day076_adam_batch32_epo4_model'))
    with open(os.path.join(save_dir, 'Day076_adam_batch32_epo4_history'), 'rb') as file:
        history=pickle.load(file)
except:
    myFit()
    model.save(os.path.join(save_dir, 'Day076_adam_batch32_epo4_model'))
    with open(os.path.join(save_dir, 'Day076_adam_batch32_epo4_history'), 'wb') as file:
        pickle.dump(history, file)

scores = model.evaluate(x_test,y_test,batch_size=200,verbose=0)
print ( " The test loss is %f ", scores)

myPlot()
# Out:
# Using real-time data augmentation.
#
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 403s 8ms/step - loss: 1.5261 - accuracy: 0.4413 - val_loss: 1.1176 - val_accuracy: 0.6008
# Epoch 2/4
# 50000/50000 [==============================] - 403s 8ms/step - loss: 1.1130 - accuracy: 0.6059 - val_loss: 0.9254 - val_accuracy: 0.6704
# Epoch 3/4
# 50000/50000 [==============================] - 400s 8ms/step - loss: 0.9641 - accuracy: 0.6594 - val_loss: 0.8839 - val_accuracy: 0.6910
# Epoch 4/4
# 50000/50000 [==============================] - 400s 8ms/step - loss: 0.8838 - accuracy: 0.6903 - val_loss: 0.7719 - val_accuracy: 0.7291
#  The test loss is %f  [0.7719025921821594, 0.7290999889373779]

# %% [markdown]
# # SGD, batch_size 32 , epochs 4

# %%
batch_size = 32
epochs = 4

model_path = os.path.join(save_dir, init_model_file_name)
model=keras.models.load_model(model_path)

opt = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

try:
    model=keras.models.load_model(os.path.join(save_dir, 'Day076_sgd_batch32_epo4_model'))
    with open(os.path.join(save_dir, 'Day076_sgd_batch32_epo4_history'), 'rb') as file:
        history=pickle.load(file)
except:
    myFit()
    model.save(os.path.join(save_dir, 'Day076_sgd_batch32_epo4_model'))
    with open(os.path.join(save_dir, 'Day076_sgd_batch32_epo4_history'), 'wb') as file:
        pickle.dump(history, file)

scores = model.evaluate(x_test,y_test,batch_size=200,verbose=0)
print ( " The test loss is %f ", scores)

myPlot()
# Out:
# Using real-time data augmentation.
#
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 387s 8ms/step - loss: 1.7279 - accuracy: 0.3592 - val_loss: 1.4521 - val_accuracy: 0.4744
# Epoch 2/4
# 50000/50000 [==============================] - 387s 8ms/step - loss: 1.3080 - accuracy: 0.5249 - val_loss: 1.1006 - val_accuracy: 0.6089
# Epoch 3/4
# 50000/50000 [==============================] - 390s 8ms/step - loss: 1.1260 - accuracy: 0.5982 - val_loss: 1.0120 - val_accuracy: 0.6366
# Epoch 4/4
# 50000/50000 [==============================] - 391s 8ms/step - loss: 1.0162 - accuracy: 0.6392 - val_loss: 0.9366 - val_accuracy: 0.6751
#  The test loss is %f  [0.93660196185112, 0.6751000285148621]

# %% [markdown]
# # RMSprop, batch_size 32 , epochs 4

# %%
batch_size = 32
epochs = 4

model_path = os.path.join(save_dir, init_model_file_name)
model=keras.models.load_model(model_path)

opt = optimizers.RMSprop(lr=0.001, rho=0.9)
model.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

try:
    model=keras.models.load_model(os.path.join(save_dir, 'Day076_RMSprop_batch32_epo4_model'))
    with open(os.path.join(save_dir, 'Day076_RMSprop_batch32_epo4_history'), 'rb') as file:
        history=pickle.load(file)
except:
    myFit()
    model.save(os.path.join(save_dir, 'Day076_RMSprop_batch32_epo4_model'))
    with open(os.path.join(save_dir, 'Day076_RMSprop_batch32_epo4_history'), 'wb') as file:
        pickle.dump(history, file)

scores = model.evaluate(x_test,y_test,batch_size=200,verbose=0)
print ( " The test loss is %f ", scores)

myPlot()
# Out:
# Using real-time data augmentation.
#
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 428s 9ms/step - loss: 1.5278 - accuracy: 0.4471 - val_loss: 1.1555 - val_accuracy: 0.5915
# Epoch 2/4
# 50000/50000 [==============================] - 412s 8ms/step - loss: 1.1113 - accuracy: 0.6114 - val_loss: 1.1463 - val_accuracy: 0.6260
# Epoch 3/4
# 50000/50000 [==============================] - 403s 8ms/step - loss: 1.0049 - accuracy: 0.6544 - val_loss: 0.9588 - val_accuracy: 0.6790
# Epoch 4/4
# 50000/50000 [==============================] - 397s 8ms/step - loss: 0.9749 - accuracy: 0.6655 - val_loss: 0.9320 - val_accuracy: 0.6843
#  The test loss is %f  [0.9320438313484192, 0.6843000054359436]

# %% [markdown]
# adam, batch_size 512 , epochs 6 [0.9374399030208588, 0.6783999800682068]
# adam, batch_size 512 , epochs 4 [1.0573681998252868, 0.6328999996185303]
# adam, batch_size 32 , epochs 4 [0.7719025921821594, 0.7290999889373779]
# SGD, batch_size 32 , epochs 4 [0.93660196185112, 0.6751000285148621]
# RMSprop, batch_size 32 , epochs 4 [0.9320438313484192, 0.6843000054359436]
